# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Akanji\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
import pandas as pd #for data manipulation and analysis
import numpy as np #it is for numerical valuse
from sklearn.model_selection import train_test_split #it porvides d/t models
from sklearn.feature_extraction.text import TfidfVectorizer #futer of extraction in nl
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
import streamlit as st #for web app development
import pickle #for saving the model

# %%
# Step 2: Load dataset
df = pd.read_csv('spam.csv', encoding='latin-1')
df.drop_duplicates(inplace=True) # Removes duplicate rows from the dataset.

# %%
df.head() # Display the first few rows of the dataset
# Step 3: Data Preprocessing
# Out:
#      v1                                                 v2 Unnamed: 2  \
# 0   ham  Go until jurong point, crazy.. Available only ...        NaN
# 1   ham                      Ok lar... Joking wif u oni...        NaN
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3   ham  U dun say so early hor... U c already then say...        NaN
# 4   ham  Nah I don't think he goes to usf, he lives aro...        NaN
#
#   Unnamed: 3 Unnamed: 4
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN

# %%
# Rename the first two columns (others will be dropped later)
df = df.rename(columns={'v1': 'label', 'v2': 'message'})

# %%
df.head()
# Out:
#   label                                            message Unnamed: 2  \
# 0   ham  Go until jurong point, crazy.. Available only ...        NaN
# 1   ham                      Ok lar... Joking wif u oni...        NaN
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3   ham  U dun say so early hor... U c already then say...        NaN
# 4   ham  Nah I don't think he goes to usf, he lives aro...        NaN
#
#   Unnamed: 3 Unnamed: 4
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN

# %%
df = df[['label', 'message']].dropna()  # Keep only relevant columns and drop NaN values
df['label'] = df['label'].map({'ham': 1, 'spam': 0})  # Convert labels to binary values

# %%
# Remove duplicates in place
df.drop_duplicates(inplace=True)
print(df.columns)
# Out:
# Index(['label', 'message'], dtype='object')

# %%
df.head(10)
# Out:
#    label                                            message
# 0      1  Go until jurong point, crazy.. Available only ...
# 1      1                      Ok lar... Joking wif u oni...
# 2      0  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      1  U dun say so early hor... U c already then say...
# 4      1  Nah I don't think he goes to usf, he lives aro...
# 5      0  FreeMsg Hey there darling it's been 3 week's n...
# 6      1  Even my brother is not like to speak with me. ...
# 7      1  As per your request 'Melle Melle (Oru Minnamin...
# 8      0  WINNER!! As a valued network customer you have...
# 9      0  Had your mobile 11 months or more? U R entitle...

# %%
y = df['label']
x = df['message']

# %%
print(x)
# Out:
# 0       Go until jurong point, crazy.. Available only ...
# 1                           Ok lar... Joking wif u oni...
# 2       Free entry in 2 a wkly comp to win FA Cup fina...
# 3       U dun say so early hor... U c already then say...
# 4       Nah I don't think he goes to usf, he lives aro...
#                               ...
# 5567    This is the 2nd time we have tried 2 contact u...
# 5568                Will Ì_ b going to esplanade fr home?
# 5569    Pity, * was in mood for that. So...any other s...
# 5570    The guy did some bitching but I acted like i'd...
# 5571                           Rofl. Its true to its name
# Name: message, Length: 5169, dtype: object

# %%
print(y)
# Out:
# 0       1
# 1       1
# 2       0
# 3       1
# 4       1
#        ..
# 5567    0
# 5568    1
# 5569    1
# 5570    1
# 5571    1
# Name: label, Length: 5169, dtype: int64

# %%
df['label'].value_counts()
df.info()
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5169 entries, 0 to 5571
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   label    5169 non-null   int64
#  1   message  5169 non-null   object
# dtypes: int64(1), object(1)
# memory usage: 121.1+ KB
# label      0
# message    0
# dtype: int64

# %%
df2 = df.copy()
#saving preprocessed data
df.to_csv('preprocessed_spam.csv', index=False)
#importing the preprocessed data

# %%
# Split data into training (80%) and testing (20%) sets
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=45)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# Create a TF-IDF vectorizer
feature_extraction = TfidfVectorizer(min_df=1, stop_words='english', lowercase=True)

# Fit and transform the training data
x_train_features = feature_extraction.fit_transform(x_train)

# Transform the test data using the same vectorizer
x_test_features = feature_extraction.transform(x_test)

# Convert labels to integers if they are not already
y_train = y_train.astype('int')
y_test = y_test.astype('int')

# %%
print(x_train_features)
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 31624 stored elements and shape (4135, 7412)>
#   Coords	Values
#   (0, 2326)	0.2254722852834918
#   (0, 2828)	0.32531494700951136
#   (0, 5006)	0.26040764115314136
#   (0, 2860)	0.2039836706707983
#   (0, 5481)	0.37754599365205205
#   (0, 338)	0.41050011503900946
#   (0, 6819)	0.26690081732884524
#   (0, 7210)	0.27308390036697067
#   (0, 3518)	0.3294517069355147
#   (0, 87)	0.41050011503900946
#   (1, 5368)	0.2621894450545844
#   (1, 4988)	0.3841986750962676
#   (1, 3900)	0.30212966199449304
#   (1, 5959)	0.27265779574597476
#   (1, 2073)	0.30611412907749547
#   (1, 7042)	0.31044549139067373
#   (1, 259)	0.28877567816249805
#   (1, 6010)	0.3406184856252708
#   (1, 2423)	0.2966938016023597
#   (1, 4082)	0.29500620730875593
#   (1, 6649)	0.2312422631457981
#   (2, 2326)	0.13814762569535394
#   (2, 6819)	0.163531026280102
#   (2, 2861)	0.251514797789921
#   (2, 5797)	0.1875105227440728
#   :	:
#   (4130, 6833)	0.6017757341632106
#   (4130, 6701)	0.5808328657203207
#   (4131, 3859)	0.6554890962200538
#   (4131, 4240)	0.7552046376556601
#   (4132, 5006)	0.3612136290545279
#   (4132, 5062)	0.4245079137343564
#   (4132, 6894)	0.2657112573797634
#   (4132, 4370)	0.5426689767096914
#   (4132, 2041)	0.5694081618493748
#   (4133, 6894)	0.1835806013765686
#   (4133, 3039)	0.20320832736178582
#   (4133, 1312)	0.2715635741810173
#   (4133, 2297)	0.3200749004628632
#   (4133, 6539)	0.26852492066125583
#   (4133, 3169)	0.2932936257987875
#   (4133, 6285)	0.3749314126739726
#   (4133, 4157)	0.3749314126739726
#   (4133, 2189)	0.3934055854909966
#   (4133, 3980)	0.3934055854909966
#   (4134, 3790)	0.29663430653430345
#   (4134, 7342)	0.3604222933967942
#   (4134, 3859)	0.3565220223908992
#   (4134, 6577)	0.40680306488385426
#   (4134, 3903)	0.5252885685272499
#   (4134, 3037)	0.4621461806999021

# %%
# Step 5: Train model
model = LogisticRegression(class_weight='balanced')
model.fit(x_train_features, y_train)
# Out:
# LogisticRegression(class_weight='balanced')

# %%
# Step 6: Evaluate model
# Predict on the test data
prediction_on_test_data = model.predict(x_test_features)

# Evaluate accuracy on the test data
test_data_accuracy = accuracy_score(y_test, prediction_on_test_data)
#This line prints the test accuracy, allowing you to see how well the model performs on unseen data.

print("Test Accuracy:", test_data_accuracy)
# Out:
# Test Accuracy: 0.9854932301740812

# %%
# Check overall input shape
print("Total data (x):", x.shape)

# Training and testing input sizes
print("Training data (x_train):", x_train.shape)
print("Testing data (x_test):", x_test.shape)

# Show first few test messages
print("\nFirst 5 test messages:\n", x_test.head())

# Check overall label shape
print("\nTotal labels (y):", y.shape)

# Training and testing label sizes
print("Training labels (y_train):", y_train.shape)
print("Testing labels (y_test):", y_test.shape)
# Show first few test labels
# Out:
# Total data (x): (5169,)
# Training data (x_train): (4135,)
# Testing data (x_test): (1034,)
#
# First 5 test messages:
#  3149    Yo! Howz u? girls never rang after india. L
# 698                  Mum ask Ì_ to buy food home...
# 5507         I want to be inside you every night...
# 1735           Why tired what special there you had
# 4214                     No dear i was sleeping :-P
# Name: message, dtype: object
#
# Total labels (y): (5169,)
# Training labels (y_train): (4135,)
# Testing labels (y_test): (1034,)

# %%
df.head(10)
# Out:
#    label                                            message
# 0      1  Go until jurong point, crazy.. Available only ...
# 1      1                      Ok lar... Joking wif u oni...
# 2      0  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      1  U dun say so early hor... U c already then say...
# 4      1  Nah I don't think he goes to usf, he lives aro...
# 5      0  FreeMsg Hey there darling it's been 3 week's n...
# 6      1  Even my brother is not like to speak with me. ...
# 7      1  As per your request 'Melle Melle (Oru Minnamin...
# 8      0  WINNER!! As a valued network customer you have...
# 9      0  Had your mobile 11 months or more? U R entitle...

# %%
df.describe()
# Out:
#              label
# count  5169.000000
# mean      0.873670
# std       0.332253
# min       0.000000
# 25%       1.000000
# 50%       1.000000
# 75%       1.000000
# max       1.000000

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# Predictions
train_preds = model.predict(x_train_features)
test_preds = model.predict(x_test_features)

# Accuracy
print("Training Accuracy:", accuracy_score(y_train, train_preds))
print("Test Accuracy:", accuracy_score(y_test, test_preds))

# Classification Report
print("\nClassification Report:\n", classification_report(y_test, test_preds))

# Confusion Matrix
print("Confusion Matrix:\n", confusion_matrix(y_test, test_preds))
# Out:
# Training Accuracy: 0.9939540507859734
# Test Accuracy: 0.9854932301740812
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.94      0.94       123
#            1       0.99      0.99      0.99       911
#
#     accuracy                           0.99      1034
#    macro avg       0.96      0.97      0.97      1034
# weighted avg       0.99      0.99      0.99      1034
#
# Confusion Matrix:
#  [[116   7]
#  [  8 903]]

# %%
input_your_mail = ["Babe! I fucking love you too !! You know? Fuck it was so good to hear your voice. I so need that. I crave it. I can't get enough. I adore you, Ahmad *kisses*"]
input_data_features = feature_extraction.transform(input_your_mail)
prediction = model.predict(input_data_features)
print("Prediction for input mail:", "ham" if prediction[0] == 1 else "spam")
# Out:
# 2025-05-19 21:05:53.128 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-19 21:05:53.142 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-19 21:05:53.154 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-19 21:05:53.160 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-19 21:05:53.172 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-19 21:05:53.177 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-19 21:05:53.183 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-19 21:05:53.191 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-19 21:05:53.197 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-19 21:05:53.202 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-19 21:05:53.210 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-19 21:05:53.213 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-19 21:05:53.217 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-19 21:05:53.228 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-19 21:05:53.230 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
y = df['label']
x = df['message']
